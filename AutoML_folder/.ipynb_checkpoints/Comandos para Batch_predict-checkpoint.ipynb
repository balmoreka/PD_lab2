# %% [markdown]
# ### Construcción del contenedor
# El directorio de trabajo en ubuntu debe ser la carpeta que se descarga de AutoML_folder
# <br>Luego ejecutar el siguiente comando:<br>
# **docker build --no-cache -t batch-folder:latest .**

# %% [markdown]
# ### Ejecución del contenedor
#
# Para ejecutar el contenedor se debe ejecutar el siguiente comando<br>
# **docker run --env-file .env --rm -it -v /mnt/c/Users/Balmore/PD/AutoML_folder/data:/data batch-folder:latest**
# <br>Tambien es posible correrlo en segundo plano utilizando -d en lugar de -it
#
# Carpeta "data" es donde se encuentran los posibles archivos a entrenar<br>
# Se puede modificar el archivo .env para colocar el nombre del archivo a entrenar (en formato parquet) en DATASET<br>
# Se debe colocar el nombre de la columna a predecir en TARGET<br>
# Se pueden modificar la cantidad de intentos necesarios para optimización en TRIALS<br>
# La cantidad maxima de features con la que el modelo se entrenara se define en FEATURE_TRAIN. Si la cantidad de features del datasets es mayor se ejecutara PCA.<br>
# Se debe seleccionar una carpeta de origen de los datos a predecir. En el .env por default se ha colocado *data/input*<br>
# Se debe seleccionar una carpeta de destino de las predicciones. En el .env por default se ha colocado *data/output*<br>
# - Luego el contenedor entrenara el modelo en base a los paramentros definidos en .env
# - Posteriormente se ejecutara el servicio donde esperara los datasets a predecir
#
# Se deja una muestra de una ejecución realizada

# %% [markdown]
# ![Funcionamiento Batch_predict.png](attachment:05534f84-b82b-4e41-8e96-16729a2e3673.png)
